# %%
pip install d3blocks --target=D:\Python Lib
# Out:
# ...
#   Obtaining dependency information for d3blocks from https://files.pythonhosted.org/packages/f0/1c/a8bb520ed6f939cebae06708b723fa10e1c99a915aeee9dd870baa8cf14b/d3blocks-1.4.7-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for numpy from https://files.pythonhosted.org/packages/da/3c/3ff05c2855eee52588f489a4e607e4a61699a0742aa03ccf641c77f9eb0a/numpy-1.26.2-cp311-cp311-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/61.2 kB ? eta -:--:--
#      ---------------------------------------- 61.2/61.2 kB 1.1 MB/s eta 0:00:00
# ...
#   Obtaining dependency information for colourmap>=1.1.10 from https://files.pythonhosted.org/packages/05/37/10bb10d990a6c986d25c5c7407ad740ee0cf047a6a0a1f297b0b92e3caaf/colourmap-1.1.16-py3-none-any.whl.metadata
# ...

# %%
pip install --upgrade pip
# Out:
# ...
#   Obtaining dependency information for pip from https://files.pythonhosted.org/packages/47/6a/453160888fab7c6a432a6e25f8afe6256d0d9f2cbd25971021da6491d899/pip-23.3.1-py3-none-any.whl.metadata
#   Using cached pip-23.3.1-py3-none-any.whl.metadata (3.5 kB)
# Using cached pip-23.3.1-py3-none-any.whl (2.1 MB)
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 23.2.1
#     Uninstalling pip-23.2.1:
#       Successfully uninstalled pip-23.2.1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests_mock FuzzyTM==0.4.0 blosc2==2.0.0 cython==0.29.21 sentencepiece==<0.0.0,>=2.0
# Out:
# Note: you may need to restart the kernel to use updated packages.
# The system cannot find the file specified.

# %%
import pandas as pd
from time import gmtime, strftime
from d3blocks import D3Blocks
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pandas as pd
#       2 from time import gmtime, strftime
# ----> 3 from d3blocks import D3Blocks
#
# ModuleNotFoundError: No module named 'd3blocks'
